# %% [markdown]
# ### KB testing

# %% [markdown]
# ### EUADR skip 1

# %%
import pandas as pd
seeds = [0,42,144]
results_df = pd.DataFrame(columns=['seed','% sample_size', '# of relations', '# of additional relations skip 1',"% of additional relations skip 1"])

dataset = "euadr"
# sample_size = 20
for seed in seeds:
    # print(f"SEED value: {seed}")
    for sample_size in range(10,101, 10):
        kb_ = pd.read_csv(f"/home/016651544/gemma/samples/{seed}/{dataset}/processed_csvs/{sample_size}_sample_val_{dataset}.csv")
        original_sample = pd.read_csv(f"/home/016651544/gemma/samples/{seed}/{dataset}/{sample_size}_sample_val_{dataset}.csv")
        full_data = pd.read_csv(f"/home/016651544/gemma/{dataset}_unmasked.csv")
        # Create tuples of entity combinations in both dataframes
        original_sample['entity_pair'] = original_sample.apply(lambda row: tuple(sorted([row['ENTITY1_TEXT'].lower(), row['ENTITY2_TEXT'].lower()])), axis=1)
        kb_['entity_pair'] = kb_.apply(lambda row: tuple(sorted([row['ent1'].lower(), row['ent2'].lower()])), axis=1)
        # Check if the entity pairs in df2 are present in df1
        kb_['is_present'] = kb_['entity_pair'].isin(original_sample['entity_pair'])
        
        # Count the matches
        matches_count = kb_['is_present'].sum()
        # print(f"Number of matching pairs: {matches_count}")
        # print(original_sample['entity_pair'].shape, kb_['entity_pair'].shape)
        percentage_additional = ((kb_['entity_pair'].shape[0] - matches_count) / original_sample['entity_pair'].shape[0]) * 100
        print(kb_.shape[0])
        results_df = results_df.append({
            'seed': seed,
           '% sample_size': sample_size,
             '# of relations': len(original_sample['entity_pair'].unique()),
            '# of additional relations skip 1': kb_['entity_pair'].shape[0],
            '% of additional relations skip 1': percentage_additional#(original_sample['entity_pair'].shape[0]+kb_['entity_pair'].shape[0])*100/original_sample['entity_pair'].shape[0]
        }, ignore_index=True)


results_df[['seed', '% sample_size','# of relations', '# of additional relations skip 1']] = results_df[['seed','% sample_size', '# of relations', '# of additional relations skip 1']].astype(int)
# Out:
# 12
# 51
# 89
# 178
# 258
# 349
# 450
# 582
# 706
# 798
# 12
# 44
# 116
# 184
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# 268
# 344
# 455
# 612
# 736
# 838
# 6
# 38
# 108
# 169
# 235
# 310
# 405
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# 556
# 745
# 837
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3497506773.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({

# %%
results_df
# Out:
#     seed  % sample_size  # of relations  # of additional relations skip 1  \
# 0      0             10              33                                12
# 1      0             20              69                                51
# 2      0             30              98                                89
# 3      0             40             128                               178
# 4      0             50             160                               258
# 5      0             60             192                               349
# 6      0             70             219                               450
# 7      0             80             245                               582
# 8      0             90             273                               706
# 9      0            100             290                               798
# 10    42             10              35                                12
# 11    42             20              67                                44
# 12    42             30             102                               116
# 13    42             40             135                               184
# 14    42             50             166                               268
# 15    42             60             192                               344
# 16    42             70             218                               455
# 17    42             80             246                               612
# 18    42             90             271                               736
# 19    42            100             289                               838
# 20   144             10              32                                 6
# 21   144             20              65                                38
# 22   144             30              97                               108
# 23   144             40             127                               169
# 24   144             50             154                               235
# 25   144             60             185                               310
# 26   144             70             212                               405
# 27   144             80             240                               556
# 28   144             90             272                               745
# 29   144            100             289                               837
#
#     % of additional relations skip 1
# 0                          34.285714
# 1                          71.830986
# 2                          83.962264
# 3                         125.352113
# 4                         145.762712
# 5                         163.849765
# 6                         181.451613
# 7                         204.929577
# 8                         221.316614
# 9                         224.788732
# 10                         34.285714
# 11                         61.971831
# 12                        109.433962
# 13                        129.577465
# 14                        151.412429
# 15                        161.502347
# 16                        183.467742
# 17                        215.492958
# 18                        230.721003
# 19                        236.056338
# 20                         17.142857
# 21                         53.521127
# 22                        101.886792
# 23                        119.014085
# 24                        132.768362
# 25                        145.539906
# 26                        163.306452
# 27                        195.774648
# 28                        233.542320
# 29                        235.774648

# %%
average_df_1 = results_df.groupby('% sample_size').mean().reset_index()

# %%
average_df_1[['% sample_size','# of relations', '# of additional relations skip 1','% of additional relations skip 1']]
# Out:
#    % sample_size  # of relations  # of additional relations skip 1  \
# 0             10       33.333333                         10.000000
# 1             20       67.000000                         44.333333
# 2             30       99.000000                        104.333333
# 3             40      130.000000                        177.000000
# 4             50      160.000000                        253.666667
# 5             60      189.666667                        334.333333
# 6             70      216.333333                        436.666667
# 7             80      243.666667                        583.333333
# 8             90      272.000000                        729.000000
# 9            100      289.333333                        824.333333
#
#    % of additional relations skip 1
# 0                         28.571429
# 1                         62.441315
# 2                         98.427673
# 3                        124.647887
# 4                        143.314501
# 5                        156.964006
# 6                        176.075269
# 7                        205.399061
# 8                        228.526646
# 9                        232.206573

# %% [markdown]
# ### EUADR skip 2

# %%
import pandas as pd
seeds = [0,42,144]
results_df = pd.DataFrame(columns=['seed','% sample_size', '# of relations', '# of additional relations skip 2',"% of additional relations skip 2"])

dataset = "euadr"
# sample_size = 20
for seed in seeds:
    print(f"SEED value: {seed}")
    for sample_size in range(10,101, 10):
        kb_ = pd.read_csv(f"/home/016651544/gemma/samples/{seed}/{dataset}/processed_csvs_skip_2/{sample_size}_sample_val_{dataset}.csv")
        original_sample = pd.read_csv(f"/home/016651544/gemma/samples/{seed}/{dataset}/{sample_size}_sample_val_{dataset}.csv")
        full_data = pd.read_csv(f"/home/016651544/gemma/{dataset}_unmasked.csv")
        # Create tuples of entity combinations in both dataframes
        original_sample['entity_pair'] = original_sample.apply(lambda row: tuple(sorted([row['ENTITY1_TEXT'].lower(), row['ENTITY2_TEXT'].lower()])), axis=1)
        kb_['entity_pair'] = kb_.apply(lambda row: tuple(sorted([row['ent1'].lower(), row['ent2'].lower()])), axis=1)
        # Check if the entity pairs in df2 are present in df1
        kb_['is_present'] = kb_['entity_pair'].isin(original_sample['entity_pair'])
        
        # Count the matches
        matches_count = kb_['is_present'].sum()
        print(f"Number of matching pairs: {matches_count}")
        # print(original_sample['entity_pair'].shape, kb_['entity_pair'].shape)
        percentage_additional = ((kb_['entity_pair'].shape[0] - matches_count) / original_sample['entity_pair'].shape[0]) * 100

        results_df = results_df.append({
            'seed': seed,
           '% sample_size': sample_size,
             '# of relations': len(original_sample['entity_pair'].unique()),
            '# of additional relations skip 2': kb_['entity_pair'].shape[0],
            '% of additional relations skip 2': percentage_additional#(original_sample['entity_pair'].shape[0]+kb_['entity_pair'].shape[0])*100/original_sample['entity_pair'].shape[0]
        }, ignore_index=True)


results_df[['seed', '% sample_size','# of relations', '# of additional relations skip 2']] = results_df[['seed','% sample_size', '# of relations', '# of additional relations skip 2']].astype(int)
# Out:
# SEED value: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# SEED value: 42
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# Number of matching pairs: 0
# SEED value: 144
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3885630333.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({

# %%
# results_df

# %%
average_df_2 = results_df.groupby('% sample_size').mean().reset_index()

# %%
average_df_2[['% sample_size','# of relations', '# of additional relations skip 2','% of additional relations skip 2']]
# Out:
#    % sample_size  # of relations  # of additional relations skip 2  \
# 0             10       33.333333                         10.333333
# 1             20       67.000000                         51.333333
# 2             30       99.000000                        126.000000
# 3             40      130.000000                        229.000000
# 4             50      160.000000                        330.666667
# 5             60      189.666667                        442.666667
# 6             70      216.333333                        588.000000
# 7             80      243.666667                        789.333333
# 8             90      272.000000                        988.333333
# 9            100      289.333333                       1132.666667
#
#    % of additional relations skip 2
# 0                         29.523810
# 1                         72.300469
# 2                        118.867925
# 3                        161.267606
# 4                        186.817326
# 5                        207.824726
# 6                        237.096774
# 7                        277.934272
# 8                        309.822362
# 9                        319.061033

# %% [markdown]
# ### SKIP 3

# %%
import pandas as pd
seeds = [0,42,144]
results_df = pd.DataFrame(columns=['seed','% sample_size', '# of relations', '# of additional relations skip 3',"% of additional relations skip 3"])

dataset = "euadr"
# sample_size = 20
for seed in seeds:
    print(f"SEED value: {seed}")
    for sample_size in range(10,101, 10):
        kb_ = pd.read_csv(f"/home/016651544/gemma/samples/{seed}/{dataset}/processed_csvs_skip_3/{sample_size}_sample_val_{dataset}.csv")
        original_sample = pd.read_csv(f"/home/016651544/gemma/samples/{seed}/{dataset}/{sample_size}_sample_val_{dataset}.csv")
        full_data = pd.read_csv(f"/home/016651544/gemma/{dataset}_unmasked.csv")
        # Create tuples of entity combinations in both dataframes
        original_sample['entity_pair'] = original_sample.apply(lambda row: tuple(sorted([row['ENTITY1_TEXT'].lower(), row['ENTITY2_TEXT'].lower()])), axis=1)
        kb_['entity_pair'] = kb_.apply(lambda row: tuple(sorted([row['ent1'].lower(), row['ent2'].lower()])), axis=1)
        # Check if the entity pairs in df2 are present in df1
        kb_['is_present'] = kb_['entity_pair'].isin(original_sample['entity_pair'])
        
        # Count the matches
        matches_count = kb_['is_present'].sum()
        print(f"Number of matching pairs: {matches_count}")
        # print(original_sample['entity_pair'].shape, kb_['entity_pair'].shape)
        percentage_additional = ((kb_['entity_pair'].shape[0] - matches_count) / original_sample['entity_pair'].shape[0]) * 100

        results_df = results_df.append({
            'seed': seed,
           '% sample_size': sample_size,
             '# of relations': len(original_sample['entity_pair'].unique()),
            '# of additional relations skip 3': kb_['entity_pair'].shape[0],
            '% of additional relations skip 3': percentage_additional#(original_sample['entity_pair'].shape[0]+kb_['entity_pair'].shape[0])*100/original_sample['entity_pair'].shape[0]
        }, ignore_index=True)


results_df[['seed', '% sample_size','# of relations', '# of additional relations skip 3']] = results_df[['seed','% sample_size', '# of relations', '# of additional relations skip 3']].astype(int)
# Out:
# SEED value: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# SEED value: 42
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# SEED value: 144
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# Number of matching pairs: 0
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# /tmp/ipykernel_193147/3995674344.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({
# Number of matching pairs: 0
# Number of matching pairs: 0

# %%
results_df
# Out:
#     seed  % sample_size  # of relations  # of additional relations skip 3  \
# 0      0             10              33                                13
# 1      0             20              69                                58
# 2      0             30              98                               116
# 3      0             40             128                               319
# 4      0             50             160                               458
# 5      0             60             192                               608
# 6      0             70             219                               784
# 7      0             80             245                               998
# 8      0             90             273                              1222
# 9      0            100             290                              1447
# 10    42             10              35                                12
# 11    42             20              67                                58
# 12    42             30             102                               157
# 13    42             40             135                               269
# 14    42             50             166                               444
# 15    42             60             192                               606
# 16    42             70             218                               801
# 17    42             80             246                              1051
# 18    42             90             271                              1295
# 19    42            100             289                              1511
# 20   144             10              32                                 6
# 21   144             20              65                                54
# 22   144             30              97                               165
# 23   144             40             127                               288
# 24   144             50             154                               397
# 25   144             60             185                               573
# 26   144             70             212                               760
# 27   144             80             240                              1058
# 28   144             90             272                              1379
# 29   144            100             289                              1515
#
#     % of additional relations skip 3
# 0                          37.142857
# 1                          81.690141
# 2                         109.433962
# 3                         224.647887
# 4                         258.757062
# 5                         285.446009
# 6                         316.129032
# 7                         351.408451
# 8                         383.072100
# 9                         407.605634
# 10                         34.285714
# 11                         81.690141
# 12                        148.113208
# 13                        189.436620
# 14                        250.847458
# 15                        284.507042
# 16                        322.983871
# 17                        370.070423
# 18                        405.956113
# 19                        425.633803
# 20                         17.142857
# 21                         76.056338
# 22                        155.660377
# 23                        202.816901
# 24                        224.293785
# 25                        269.014085
# 26                        306.451613
# 27                        372.535211
# 28                        432.288401
# 29                        426.760563

# %%
average_df_3 = results_df.groupby('% sample_size').mean().reset_index()

# %%
average_df_3[['% sample_size','# of relations', '# of additional relations skip 3','% of additional relations skip 3']]
# Out:
#    % sample_size  # of relations  # of additional relations skip 3  \
# 0             10       33.333333                         10.333333
# 1             20       67.000000                         56.666667
# 2             30       99.000000                        146.000000
# 3             40      130.000000                        292.000000
# 4             50      160.000000                        433.000000
# 5             60      189.666667                        595.666667
# 6             70      216.333333                        781.666667
# 7             80      243.666667                       1035.666667
# 8             90      272.000000                       1298.666667
# 9            100      289.333333                       1491.000000
#
#    % of additional relations skip 3
# 0                         29.523810
# 1                         79.812207
# 2                        137.735849
# 3                        205.633803
# 4                        244.632768
# 5                        279.655712
# 6                        315.188172
# 7                        364.671362
# 8                        407.105538
# 9                        420.000000

# %%
average_df_1
# Out:
#    % sample_size  seed  # of relations  # of additional relations skip 1  \
# 0             10  62.0       33.333333                         10.000000
# 1             20  62.0       67.000000                         44.333333
# 2             30  62.0       99.000000                        104.333333
# 3             40  62.0      130.000000                        177.000000
# 4             50  62.0      160.000000                        253.666667
# 5             60  62.0      189.666667                        334.333333
# 6             70  62.0      216.333333                        436.666667
# 7             80  62.0      243.666667                        583.333333
# 8             90  62.0      272.000000                        729.000000
# 9            100  62.0      289.333333                        824.333333
#
#    % of additional relations skip 1
# 0                         28.571429
# 1                         62.441315
# 2                         98.427673
# 3                        124.647887
# 4                        143.314501
# 5                        156.964006
# 6                        176.075269
# 7                        205.399061
# 8                        228.526646
# 9                        232.206573

# %%
average_df_2
# Out:
#    % sample_size  seed  # of relations  # of additional relations skip 2  \
# 0             10  62.0       33.333333                         10.333333
# 1             20  62.0       67.000000                         51.333333
# 2             30  62.0       99.000000                        126.000000
# 3             40  62.0      130.000000                        229.000000
# 4             50  62.0      160.000000                        330.666667
# 5             60  62.0      189.666667                        442.666667
# 6             70  62.0      216.333333                        588.000000
# 7             80  62.0      243.666667                        789.333333
# 8             90  62.0      272.000000                        988.333333
# 9            100  62.0      289.333333                       1132.666667
#
#    % of additional relations skip 2
# 0                         29.523810
# 1                         72.300469
# 2                        118.867925
# 3                        161.267606
# 4                        186.817326
# 5                        207.824726
# 6                        237.096774
# 7                        277.934272
# 8                        309.822362
# 9                        319.061033

# %%
average_df_3
# Out:
#    % sample_size  seed  # of relations  # of additional relations skip 3  \
# 0             10  62.0       33.333333                         10.333333
# 1             20  62.0       67.000000                         56.666667
# 2             30  62.0       99.000000                        146.000000
# 3             40  62.0      130.000000                        292.000000
# 4             50  62.0      160.000000                        433.000000
# 5             60  62.0      189.666667                        595.666667
# 6             70  62.0      216.333333                        781.666667
# 7             80  62.0      243.666667                       1035.666667
# 8             90  62.0      272.000000                       1298.666667
# 9            100  62.0      289.333333                       1491.000000
#
#    % of additional relations skip 3
# 0                         29.523810
# 1                         79.812207
# 2                        137.735849
# 3                        205.633803
# 4                        244.632768
# 5                        279.655712
# 6                        315.188172
# 7                        364.671362
# 8                        407.105538
# 9                        420.000000

# %%
df_final = pd.merge(average_df_1, average_df_2, on = ['% sample_size','# of relations'], how="inner")
df_final = pd.merge(df_final, average_df_3, on = ['% sample_size','# of relations'], how="inner")

# %%
df_final.drop(columns = ['seed','seed_x','seed_y'],inplace=True)

# %%
df_final
# Out:
#    % sample_size  # of relations  # of additional relations skip 1  \
# 0             10       33.333333                         10.000000
# 1             20       67.000000                         44.333333
# 2             30       99.000000                        104.333333
# 3             40      130.000000                        177.000000
# 4             50      160.000000                        253.666667
# 5             60      189.666667                        334.333333
# 6             70      216.333333                        436.666667
# 7             80      243.666667                        583.333333
# 8             90      272.000000                        729.000000
# 9            100      289.333333                        824.333333
#
#    % of additional relations skip 1  # of additional relations skip 2  \
# 0                         28.571429                         10.333333
# 1                         62.441315                         51.333333
# 2                         98.427673                        126.000000
# 3                        124.647887                        229.000000
# 4                        143.314501                        330.666667
# 5                        156.964006                        442.666667
# 6                        176.075269                        588.000000
# 7                        205.399061                        789.333333
# 8                        228.526646                        988.333333
# 9                        232.206573                       1132.666667
#
#    % of additional relations skip 2  # of additional relations skip 3  \
# 0                         29.523810                         10.333333
# 1                         72.300469                         56.666667
# 2                        118.867925                        146.000000
# 3                        161.267606                        292.000000
# 4                        186.817326                        433.000000
# 5                        207.824726                        595.666667
# 6                        237.096774                        781.666667
# 7                        277.934272                       1035.666667
# 8                        309.822362                       1298.666667
# 9                        319.061033                       1491.000000
#
#    % of additional relations skip 3
# 0                         29.523810
# 1                         79.812207
# 2                        137.735849
# 3                        205.633803
# 4                        244.632768
# 5                        279.655712
# 6                        315.188172
# 7                        364.671362
# 8                        407.105538
# 9                        420.000000

# %%
columns = ['# of relations','# of additional relations skip 1','# of additional relations skip 2','# of additional relations skip 3',
       '% of additional relations skip 1', '% of additional relations skip 2', 
       '% of additional relations skip 3']
df_final[columns] = df_final[columns].round(2)
df_final['sample_size'] = [35,71,106,142,177,213,248,284,319,355]
df_final
# Out:
#    % sample_size  # of relations  # of additional relations skip 1  \
# 0             10           33.33                             10.00
# 1             20           67.00                             44.33
# 2             30           99.00                            104.33
# 3             40          130.00                            177.00
# 4             50          160.00                            253.67
# 5             60          189.67                            334.33
# 6             70          216.33                            436.67
# 7             80          243.67                            583.33
# 8             90          272.00                            729.00
# 9            100          289.33                            824.33
#
#    % of additional relations skip 1  # of additional relations skip 2  \
# 0                             28.57                             10.33
# 1                             62.44                             51.33
# 2                             98.43                            126.00
# 3                            124.65                            229.00
# 4                            143.31                            330.67
# 5                            156.96                            442.67
# 6                            176.08                            588.00
# 7                            205.40                            789.33
# 8                            228.53                            988.33
# 9                            232.21                           1132.67
#
#    % of additional relations skip 2  # of additional relations skip 3  \
# 0                             29.52                             10.33
# 1                             72.30                             56.67
# 2                            118.87                            146.00
# 3                            161.27                            292.00
# 4                            186.82                            433.00
# 5                            207.82                            595.67
# 6                            237.10                            781.67
# 7                            277.93                           1035.67
# 8                            309.82                           1298.67
# 9                            319.06                           1491.00
#
#    % of additional relations skip 3  sample_size
# 0                             29.52           35
# 1                             79.81           71
# 2                            137.74          106
# 3                            205.63          142
# 4                            244.63          177
# 5                            279.66          213
# 6                            315.19          248
# 7                            364.67          284
# 8                            407.11          319
# 9                            420.00          355

# %%
cols= [ 'sample_size','# of relations','% of additional relations skip 1', '% of additional relations skip 2', 
       '% of additional relations skip 3']
df_final[cols]
# Out:
#    sample_size  # of relations  % of additional relations skip 1  \
# 0           35           33.33                             28.57
# 1           71           67.00                             62.44
# 2          106           99.00                             98.43
# 3          142          130.00                            124.65
# 4          177          160.00                            143.31
# 5          213          189.67                            156.96
# 6          248          216.33                            176.08
# 7          284          243.67                            205.40
# 8          319          272.00                            228.53
# 9          355          289.33                            232.21
#
#    % of additional relations skip 2  % of additional relations skip 3
# 0                             29.52                             29.52
# 1                             72.30                             79.81
# 2                            118.87                            137.74
# 3                            161.27                            205.63
# 4                            186.82                            244.63
# 5                            207.82                            279.66
# 6                            237.10                            315.19
# 7                            277.93                            364.67
# 8                            309.82                            407.11
# 9                            319.06                            420.00

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(df_final['sample_size'], df_final['% of additional relations skip 1'], label='2-Hop', marker='o')
plt.plot(df_final['sample_size'], df_final['% of additional relations skip 2'], label='3-Hop', marker='o')
plt.plot(df_final['sample_size'], df_final['% of additional relations skip 3'], label='4-Hop', marker='o')

# Labeling
# Adjusting the x-axis and y-axis as per request
plt.ylim(0, 600)  # Y-axis now goes up to 500
plt.xlim(0, 360)  # X-axis now goes up to 800
# plt.title('Percentage of Additional Relations by Hop Level')
plt.xlabel('# of samples')
plt.ylabel('% of new binary relations')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the dataset you want to filter by
selected_dataset = "GAD"  # Change to "EU-ADR" if needed

# Plotting
plt.figure(figsize=(8, 6))
for model in ["BioBERT", "Gemma-2b", "Gemma-7b", "LLaMA2-7b"]:
    # Filter data for each model and plot across metrics for the selected dataset
    filtered_data = df[df['Dataset'] == selected_dataset]
    filtered_data = filtered_data[['Metric', 'Dataset', model]].melt(id_vars=['Metric', 'Dataset'], var_name='Model', value_name='Score')
    metric_dataset = filtered_data['Metric'] + " (" + filtered_data['Dataset'] + ")"
    plt.plot(metric_dataset, filtered_data['Score'], marker='o', label=model)

plt.title(f'Model Performance in {selected_dataset} Dataset Across Metrics')
plt.xlabel('Metric (Dataset)')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend(title='Model')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 10
#       7 plt.figure(figsize=(8, 6))
#       8 for model in ["BioBERT", "Gemma-2b", "Gemma-7b", "LLaMA2-7b"]:
#       9     # Filter data for each model and plot across metrics for the selected dataset
# ---> 10     filtered_data = df[df['Dataset'] == selected_dataset]
#      11     filtered_data = filtered_data[['Metric', 'Dataset', model]].melt(id_vars=['Metric', 'Dataset'], var_name='Model', value_name='Score')
#      12     metric_dataset = filtered_data['Metric'] + " (" + filtered_data['Dataset'] + ")"
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt

# Define the dataset you want to filter by
selected_dataset = "EU-ADR"  # Change to "EU-ADR" if needed

# Plotting
plt.figure(figsize=(8, 6))
for model in ["BioBERT", "Gemma-2b", "Gemma-7b", "LLaMA2-7b"]:
    # Filter data for each model and plot across metrics for the selected dataset
    filtered_data = df[df['Dataset'] == selected_dataset]
    filtered_data = filtered_data[['Metric', 'Dataset', model]].melt(id_vars=['Metric', 'Dataset'], var_name='Model', value_name='Score')
    metric_dataset = filtered_data['Metric'] + " (" + filtered_data['Dataset'] + ")"
    plt.plot(metric_dataset, filtered_data['Score'], marker='o', label=model)

plt.title(f'Model Performance in {selected_dataset} Dataset Across Metrics')
plt.xlabel('Metric (Dataset)')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend(title='Model')
plt.grid(True)
plt.tight_layout()
plt.show()
